# %% [markdown]
# # Tasca M4 T01

# %% [markdown]
# ### Descripció
# ### Utilitzant les biblioteques de visualització de dades Matplotlib o Seaborn, realitza els següents exercicis.
#
# - ## RECORDA
#
# ### En la ciència de dades una de les tasques més importants és l'anàlisi. Una gràfica sempre ha d'anar acompanyada d'una explicació d'aquesta. Aporta informació.

# %% [markdown]
# ## Exercici 1
# Descarrega el dataset adjunt preu lloguer per trimestre i barri.csv extret de la web OpenDataBCN i resumeix-lo estadísticament i gràficament.
#
# Crea almenys una visualització per:
# - Una variable categòrica (Districte o Barri)
# - Una variable numèrica (Preu)
# - Una variable numèrica i una categòrica (Districte i Preu)
# - Dues variables numèriques (Any o Trimestre i Preu)
# - Tres variables (Barri o Districte, Trimestre i Preu)

# %%
## importo les llibreries que necessito per l'exercici
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns #Importo llibreries i baixo la bdd
import plotly.express as px #
preuslloguer = pd.read_csv('/Users/angelssastrenadal/Downloads/ITAcademy_Exercicis/Sprint4/preu lloguer per trimestre i barri.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None) #Miro totes les files i columnes
preuslloguer = preuslloguer.sort_values(by='Preu',ascending=True) #Ordeno per preu de mes petit a mes gran
preuslloguer
# Out:
#       Any  Trimestre  Codi_Districte        Nom_Districte  Codi_Barri  \
# 422  2021          3               9          Sant Andreu          58
# 420  2021          3               8           Nou Barris          56
# 418  2021          3               8           Nou Barris          54
# 265  2021          2               8           Nou Barris          47
# 411  2021          3               8           Nou Barris          47
# 130  2021          1               9          Sant Andreu          58
# 57   2021          1               9          Sant Andreu          58
# 406  2021          3               7       Horta-Guinardó          42
# 157  2021          2               3       Sants-Montjuïc          12
# 187  2021          2               7       Horta-Guinardó          42
# 303  2021          3               3       Sants-Montjuïc          12
# 376  2021          3               3       Sants-Montjuïc          12
# ...

# %%
preuslloguer.info() #miro la info de les variables i tamany 583 files i columnes, 4 var numeriques i 4 alfanumeriques
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 584 entries, 422 to 164
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Any             584 non-null    int64
#  1   Trimestre       584 non-null    int64
#  2   Codi_Districte  584 non-null    int64
#  3   Nom_Districte   584 non-null    object
#  4   Codi_Barri      584 non-null    int64
#  5   Nom_Barri       584 non-null    object
#  6   Lloguer_mitja   584 non-null    object
#  7   Preu            584 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 41.1+ KB

# %% [markdown]
# - Veig que es un resum del 2021 per districte i barri del preu de lloguer mensual, amb 584 registres i 8 columnes
# - Veig que la variable 'Preu' està com object i s'hauria de canviar a un nombre int64 o float64 per poder fer un resum estadístic
# - Veig que hi han preus que son Euros/mes, altres Euros metro quadrat/mes, i altres amb el simbol '--' on hi falten dades (pero no hi ha 0), per tant s'haurà de homogeneitzar la bdd

# %%
preuslloguer['Preu']=pd.to_numeric(preuslloguer['Preu'], errors='coerce') # Canvio a un valor float64
preuslloguer.dtypes #comprovo
# Out:
# Any                 int64
# Trimestre           int64
# Codi_Districte      int64
# Nom_Districte      object
# Codi_Barri          int64
# Nom_Barri          object
# Lloguer_mitja      object
# Preu              float64
# dtype: object

# %%
duplicats = preuslloguer.duplicated() #Miro si hi han files/registres duplicats
num_duplicates = duplicats.sum()
print("Hi han", num_duplicates, "duplicats.")
# Out:
# Hi han 0 duplicats.

# %%
preuslloguer['Lloguer_mitja'].unique() #Veiem els valors per veure si hi ha alguna tipologia mes de Lloguer mitjà de les que hem observat anteriorment.
# Out:
# array(['Lloguer mitjà per superfície (Euros/m2 mes)',
#        'Lloguer mitjà mensual (Euros/mes)'], dtype=object)

# %%
  # Filtrem i creem un nou dataframe per veure només el lloguer mitjà mensual (Euros/mes)
filtre = preuslloguer['Lloguer_mitja'].str.contains('Lloguer mitjà mensual')
lloguerEurosmes = preuslloguer.loc[filtre]
lloguerEurosmes
# Out:
#       Any  Trimestre  Codi_Districte        Nom_Districte  Codi_Barri  \
# 57   2021          1               9          Sant Andreu          58
# 157  2021          2               3       Sants-Montjuïc          12
# 187  2021          2               7       Horta-Guinardó          42
# 303  2021          3               3       Sants-Montjuïc          12
# 192  2021          2               8           Nou Barris          47
# 349  2021          3               9          Sant Andreu          58
# 347  2021          3               8           Nou Barris          56
# 345  2021          3               8           Nou Barris          54
# 338  2021          3               8           Nou Barris          47
# 333  2021          3               7       Horta-Guinardó          42
# 41   2021          1               7       Horta-Guinardó          42
# 199  2021          2               8           Nou Barris          54
# ...

# %%
lloguerEurosmes.isnull().sum()  #Miro si te NaNs
# Out:
# Any                0
# Trimestre          0
# Codi_Districte     0
# Nom_Districte      0
# Codi_Barri         0
# Nom_Barri          0
# Lloguer_mitja      0
# Preu              22
# dtype: int64

# %%
# Substitueixo els valors NaN de la columna "Preu" amb la mitjana per Districte
lloguerEurosmes_copy = lloguerEurosmes.copy()

lloguerEurosmes_copy.loc['Preu'] = lloguerEurosmes.groupby('Nom_Districte')['Preu'].apply(lambda x: x.fillna(x.mean()))
 
#Ara torno a calcular la mitjana per districte
mitjanaxdistricte_nonulls = lloguerEurosmes.groupby('Nom_Districte')['Preu'].mean() #Agrupo per districte i faig mitja de nou
mitjanaxdistricte_nonulls = mitjanaxdistricte_nonulls.sort_values(ascending=False) #Ordeno
mitjanaxdistricte_nonulls = mitjanaxdistricte_nonulls.reset_index() #Faig un nou dataframe
mitjanaxdistricte_nonulls
# Out:
#          Nom_Districte         Preu
# 0  Sarrià-Sant Gervasi  1271.212500
# 1            Les Corts  1214.066667
# 2             Eixample  1000.545833
# 3           Sant Martí   916.450000
# 4               Gràcia   877.265000
# 5         Ciutat Vella   858.925000
# 6       Sants-Montjuïc   798.932143
# 7       Horta-Guinardó   765.007500
# 8          Sant Andreu   721.196154
# 9           Nou Barris   664.292500

# %% [markdown]
# Veiem que el barri mes car es Sarrià-Sant Gervasi que es gairebé el doble que Nou Barris

# %%
  # Filtrem i creem un nou dataframe per veure només el "Lloguer mitjà per superfície (Euros/m2 mes)""	
filtre2 = preuslloguer['Lloguer_mitja'].str.contains('Lloguer mitjà per superfície')
lloguerEurossuperficie = preuslloguer.loc[filtre2]
lloguerEurossuperficie
# Out:
#       Any  Trimestre  Codi_Districte        Nom_Districte  Codi_Barri  \
# 422  2021          3               9          Sant Andreu          58
# 420  2021          3               8           Nou Barris          56
# 418  2021          3               8           Nou Barris          54
# 265  2021          2               8           Nou Barris          47
# 411  2021          3               8           Nou Barris          47
# 130  2021          1               9          Sant Andreu          58
# 406  2021          3               7       Horta-Guinardó          42
# 376  2021          3               3       Sants-Montjuïc          12
# 230  2021          2               3       Sants-Montjuïc          12
# 272  2021          2               8           Nou Barris          54
# 114  2021          1               7       Horta-Guinardó          42
# 260  2021          2               7       Horta-Guinardó          42
# ...

# %%
lloguerEurossuperficie.isnull().sum()  #Miro si te NaNs
# Out:
# Any                0
# Trimestre          0
# Codi_Districte     0
# Nom_Districte      0
# Codi_Barri         0
# Nom_Barri          0
# Lloguer_mitja      0
# Preu              22
# dtype: int64

# %%
# Substitueixo els valors NaN de la columna "Preu" amb la mitjana per Districte
lloguerEurossuperficie_copia = lloguerEurossuperficie.copy() #faig una copia de la bdd

lloguerEurossuperficie_copia.loc['Preu'] = lloguerEurossuperficie.groupby('Nom_Barri')['Preu'].apply(lambda x: x.fillna(x.mean()))
 
#Ara torno a calcular la mitjana per districte
mitjanaxdistricteisup = lloguerEurossuperficie_copy.groupby('Nom_Districte')['Preu'].mean() #Agrupo per districte i faig mitja de nou
mitjanaxdistricteisup = mitjanaxdistricteisup.sort_values(ascending=False) #Ordeno
mitjanaxdistricteisup = mitjanaxdistricteisup.reset_index() #Faig un nou dataframe
mitjanaxdistricteisup
# Out:
#          Nom_Districte       Preu
# 0  Sarrià-Sant Gervasi  15.012500
# 1            Les Corts  14.008333
# 2         Ciutat Vella  13.775000
# 3           Sant Martí  13.440000
# 4               Gràcia  13.380000
# 5             Eixample  13.300000
# 6       Sants-Montjuïc  12.678571
# 7       Horta-Guinardó  11.987500
# 8          Sant Andreu  11.153846
# 9           Nou Barris  10.922500

# %% [markdown]
# Veiem aqui que la diferencia entre la mitja m2 del barri mes car, al mes econòmic no es tant extrema com els preus mensuals mitjos.

# %% [markdown]
# Faig el resum estadistic del **Lloguer mitjà per superfície (Euros/m2 mes)** per districte

# %%
mitjanaxdistricteisup.describe().round(2) #Faig el resum i arrodoneixo els decimals a 2
# Out:
#         Preu
# count  10.00
# mean   12.97
# std     1.29
# min    10.92
# 25%    12.16
# 50%    13.34
# 75%    13.69
# max    15.01

# %% [markdown]
# Faig el resum estadistic del **Lloguer mitjà Euros/mes** per districte

# %%
mitjanaxdistricte_nonulls.describe().round(2) #Faig el resum i arrodoneixo els decimals a 2
# Out:
# count      10.00
# mean      908.79
# std       201.17
# min       664.29
# 25%       773.49
# 50%       868.10
# 75%       979.52
# max      1271.21
# Name: Preu, dtype: float64

# %% [markdown]
# **Analisi Estadístic mitja preu mensual** A la mitja mensual per districte veiem que un 75% dels lloguers s'acosten molt a la mitja. Tantmateix la mitja s'acosta mes a la mínima que a la màxima,per tant serà una distribució que s'acosta a l'esquerra. La desviació estandard es bastant petita per el que indica que la majoria dels lloguers estàn aprop de la mitjana.

# %% [markdown]
# **Analisi Estadístic mitja preu/m2** Veiem que un 50% dels lloguers s'acosten molt a la mitja. Tantmateix la mitja esta entre la minima i la màxima ,per tant serà una distribució centrada. Tot i que la desviació estandard en lloguer mitjà per Euros/mes es encara mes petita que en la mitja mensual per districte per el que indica que la majoria dels lloguers estàn aprop de la mitjana.

# %% [markdown]
# **Faig una visualització numèrica (Preu):**

# %%
import plotly.express as px #plotly express es un modul de plotly per fer plots d'una manera ràpida

px.violin(lloguerEurosmes,x='Preu', title='Preus de lloguer mensual') #miro la distribució del preu de lloguer mensual

#Per guardar com a imatge nomes s'ha de fer click al gràfic i "Download plot as .png"
# Out:
# <div>                            <div id="3762b867-f6b0-4b9f-972c-0a1d59fb47ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3762b867-f6b0-4b9f-972c-0a1d59fb47ef")) {                    Plotly.newPlot(                        "3762b867-f6b0-4b9f-972c-0a1d59fb47ef",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"Preu=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","offsetgroup":"","orientation":"h","scalegroup":"True","showlegend":false,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,1004.7,1009.5,1017.0,1024.4,1024.4,1040.2,1040.7,1052.8,1070.1,1072.9,1074.7,1114.9,1159.6,1162.9,1168.4,1176.7,1196.3,1205.3,1214
# ...

# %% [markdown]
# Veiem que es una distribució amb gran densitat a la mitjana, la majoria de lloguers s'apropen a la mitjana com i la distribució s'acosta mes a l'esquerra (al mínim) com deiem al resum estadístic, però on també hi ha molta diferencia entre el mínim i el màxim...

# %% [markdown]
# **Faig una visualització categòrica (Districte):**

# %%
#Creu una taula amb el nombre de lloguers per districte
lloguerEurosmes_copia = lloguerEurosmes.groupby('Nom_Districte').size().reset_index(name='Num_Lloguers')
#Compto el nro de lloguers i faig una nova taula
lloguerEurosmes_copia = lloguerEurosmes_copia.sort_values(by='Num_Lloguers', ascending=False)
lloguerEurosmes_copia
# Out:
#          Nom_Districte  Num_Lloguers
# 5           Nou Barris            52
# 3       Horta-Guinardó            44
# 7           Sant Martí            40
# 8       Sants-Montjuïc            32
# 6          Sant Andreu            28
# 1             Eixample            24
# 9  Sarrià-Sant Gervasi            24
# 2               Gràcia            20
# 0         Ciutat Vella            16
# 4            Les Corts            12

# %%
#Faig la visualització amb seaborn amb un heatmap
sns.set_style("whitegrid") #estil del gràfic amb fons blanc
sns.heatmap(lloguerEurosmes_copia.pivot_table(index='Nom_Districte', values='Num_Lloguers'), cmap="Blues") #Faig un grafic de mapa de calor/intensitat d'un valor
plt.ylabel("Nom_Districte") #La variable categorica Districte 
plt.title("Nombre de lloguers per Districte") #Poso el titol
plt.savefig("1varcategoricaHeatmapLloguersDistricte.png") #Guardo la imatge

# Creo un heatmap amb el nombre de lloguers, veiem mes fosc Nou Barris o Horta on hi ha mes lloguers
# I molt claret a Les corts on gairebé no hi han

# %% [markdown]
# A la visualització veiem el que deiem al resum estadístic.Per preu mensual mitjà veiem que els lloguers mes nombrosos en aquesta bdd son al voltant dels 800€ i es una distribució com deiem al resum estadístic pronunciada cap a l'esquerra. Per preu m2, es una distribució mes centrada, ja que la majoria de preus m2 s'acosten a la mitja 12,97€/m2

# %% [markdown]
# **Visualització per variable numèrica i una categòrica (Districte i Preu)**

# %%
Faig 2 visualitzacions,1 amb Matplot i 1 amb Seaborn

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import plotly.express as px

fig, ax = plt.subplots(figsize=(7,7)) #Poso el tamany
ax.bar(data=mitjanaxdistricte_nonulls, x='Nom_Districte', height='Preu') #Poso les dades a agafar Districte i preu i els eixos
ax.set_xticks(range(len(mitjanaxdistricte_nonulls)))
ax.set_xticklabels(mitjanaxdistricte_nonulls['Nom_Districte'], rotation=90) #Poso els noms dels districtes en posicio vertical perque es puguin llegir.
ax.set_xlabel('Nom_Districte')
ax.set_ylabel('Preu')
ax.set_title('Preu mig per Districte')
plt.legend(['Preu mig'])
plt.savefig("2varNumiCatPreumigMatplot.png")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.swarmplot(x=mitjanaxdistricte_nonulls["Nom_Districte"], y=mitjanaxdistricte_nonulls["Preu"], size=10)
sns.color_palette("husl")
plt.xticks(rotation=90)
plt.savefig("2VarNumCatGraficDistrictePreu.png")

# %% [markdown]
# **Dues variables numèriques (Any o Trimestre i Preu)**

# %% [markdown]
# Com es tot el mateix any (2021), faig una visualització per trimestre

# %%
#Miro la mitja per trimestre de preu m2
LloguerEurossuperficiecopia = lloguerEurossuperficie_copy #Faig una copia de la bdd per fer un nou dataset
mitjanaxtrimestreisup = lloguerEurossuperficie_copy.groupby('Trimestre')['Preu'].mean().reset_index() #Agrupo per districte i faig mitja 
mitjanaxtrimestreisup = mitjanaxtrimestreisup.sort_values(by='Trimestre', ascending=True) # Ordeno
mitjanaxtrimestreisup
# Out:
#    Trimestre       Preu
# 0        1.0  12.691045
# 1        2.0  12.564706
# 2        3.0  12.771642
# 3        4.0  12.855882

# %%
#Miro la mitja per trimestre de preu mensual
mitjanaxtrimestremes = lloguerEurosmes_copy.groupby('Trimestre')['Preu'].mean().reset_index() #Agrupo per districte i faig mitja de nou
mitjanaxtrimestremes = mitjanaxtrimestremes.sort_values(by='Trimestre', ascending=True) #Ordeno
mitjanaxtrimestremes
# Out:
#    Trimestre        Preu
# 0        1.0  856.457716
# 1        2.0  842.283796
# 2        3.0  867.002922
# 3        4.0  872.611194

# %% [markdown]
# Veig que ambdos casos el lloguer mig baixa lleugerament i al ultim trimestre repunta una mica

# %%
plt.figure(figsize=(10, 8)) #Incremento el tamany desde la llibreria de Matplot en polsades

sns.violinplot(x="Trimestre", y="Preu", data=lloguerEurossuperficie,palette='rainbow') #Faig un grafic de distribucio violi de tots els preus de lloguer per m2
plt.title("Preus metre cuadrat per Trimestre") #Poso el titol
plt.savefig("2varNumPreusm2Trimestre.png");

# %% [markdown]
# Veiem que per alguna raó en el 2T varen haver alguns lloguers mes baixos que durant la resta del any i mes desviació entre els minims i el màxims de preu. Al 4T hi van haver els preus mes alts. Pero son distribucions bastants similars per trimestre sense massa variació.

# %%
plt.figure(figsize=(10, 8)) #Incremento el tamany desde la llibreria de Matplot en polsades
sns.boxplot(x="Trimestre", y="Preu", data=lloguerEurosmes,palette='rainbow')
plt.title("Preus mensuals per Trimestre") #Poso el titol
plt.savefig("2varNumPreusmensualsTrimestre.png"); #Guardo la imatge

# %% [markdown]
# En lloguers mensuals, al 4rt Trimestre també veiem la mitja mes alta i al 2on trimestre també quan hi va haver mes desviació entre mínim i màxim. També veiem que hi ha força outliers, sobretot al T2.

# %% [markdown]
# **- Tres variables (Barri, Trimestre i Preu)**

# %%
copialloguerEurosmes= lloguerEurosmes.copy()#Faig una copia de la bdd per fer un nou dataset
copialloguerEurosmes= copialloguerEurosmes.loc[:, ["Preu","Trimestre","Nom_Barri"]].reset_index()
fig = px.scatter(copialloguerEurosmes, x="Preu", y="Trimestre", color="Nom_Barri")
fig.update_layout(yaxis=dict( 
    tickvals=[1, 2, 3, 4],
    ticktext=['1T', '2T', '3T', '4T'] ))#He posat aquesta funció perque m'agafava trimestres 1,5 2,5 i 3,5 perque agafi nomes els 4 valors
fig.show()
# Out:
# <div>                            <div id="6f081678-6719-4691-82bb-fa663b3bf48a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f081678-6719-4691-82bb-fa663b3bf48a")) {                    Plotly.newPlot(                        "6f081678-6719-4691-82bb-fa663b3bf48a",                        [{"hovertemplate":"Nom_Barri=Bar\u00f3 de Viver<br>Preu=%{x}<br>Trimestre=%{y}<extra></extra>","legendgroup":"Bar\u00f3 de Viver","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bar\u00f3 de Viver","orientation":"v","showlegend":true,"x":[null,null,447.5,616.7],"xaxis":"x","y":[1,3,2,4],"yaxis":"y","type":"scatter"},{"hovertemplate":"Nom_Barri=la Marina del Prat Vermell<br>Preu=%{x}<br>Trimestre=%{y}<extra></extra>","legendgroup":"la Marina
# ...

# %% [markdown]
# Podem observar que la majoria de barris tenen un preu entre 600 i 1000€ al mes, que el record de lloguer mensual l'any 2021, va ser al 3T amb 1816€ a Pedralbes
# I el mínim van ser 447€ al barri Baró de Viver al 2T.
# Els barris mes cars son Pedralbes i Tres Torres i els mes econòmics, Ciutat meridiana, Baró de Viver i Trinitat Nova.

# %% [markdown]
# ## Exercici 2
# Exporta els gràfics com imatges o com HTML.

# %%
#Els he pujat a Github com arxius

# %% [markdown]
# ## Exercici 3

# %% [markdown]
# **Altres visualtizacions: Cuatre variables (Districte, Trimestre, Preu i Nombre de lloguers)**

# %%
NroLloguersxdistricte = lloguerEurosmes_copy.groupby('Codi_Districte').size().reset_index(name='NroLloguersxdistricte') # Agrupo les dades per Districte i compto el número de lloguers 

merged = pd.merge(lloguerEurosmes_copy, NroLloguersxdistricte, on='Codi_Districte')# Unim les dades agrupades amb l'original

# Creo el scatter plot de la unió amb Plotly Express 
import plotly
import plotly.express as px
fig = px.scatter(merged, x="Preu", y="Trimestre", size="NroLloguersxdistricte", color="Codi_Districte",hover_name="Nom_Districte",log_x=True, size_max=50)
#Eix x el preu, eix vertical el trimestre, el tamany dels cercles és el nombre de lloguers i quan hi passes el ratolí (hover) et dona les dades per Nom de districte.
fig.update_layout(yaxis=dict( 
    tickvals=[1, 2, 3, 4],
    ticktext=['1T', '2T', '3T', '4T'] ))#He posat aquesta funció perque m'agafava trimestres 1,5 2,5 i 3,5 perque agafi nomes els 4 valors
fig.show()
#Puc guardar la imatge simplement fent click al grafic, al botó "Download plot as png"
# Out:
# <div>                            <div id="e33ac389-c875-4755-a505-2d7e9abcf57e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e33ac389-c875-4755-a505-2d7e9abcf57e")) {                    Plotly.newPlot(                        "e33ac389-c875-4755-a505-2d7e9abcf57e",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Preu=%{x}<br>Trimestre=%{y}<br>NroLloguersxdistricte=%{marker.size}<br>Codi_Districte=%{marker.color}<extra></extra>","hovertext":["Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andreu","Sant Andre
# ...

# %% [markdown]
# Veiem que els preus mes baixos i mes nombrosos on els cercles son mes grans,  son del codi de districte 8 a 10 (Nou Barris, Sant Andreu i Sant Martí )
# Que van haver lloguers força baixos al 2T del 2021 a Sant Andreu i Nou Barris i alhora mes diferencia entre el preu màxim i el mínim de tots els lloguers globalment.
# Que a les Corts és on hi ha menys lloguers (cercles mes petits) i que hi ha força concentració de lloguers entre els
# 600 i els 1000€.

# %% [markdown]
# **Altres visualitzacions: Una visualització Nombre de lloguers per preu, amb preus mensuals i preus m2:**

# %%
sns.displot(lloguerEurosmes_copy['Preu'],kde=True)
plt.title("Preus mensuals per Districte") #Poso el titol
plt.ylabel("Nombre de lloguers")
plt.savefig("Preusmensualsquantitat.png");
sns.displot(lloguerEurossuperficie['Preu'],kde=True)
plt.title("Preus m2 per Districte") #Poso el titol
plt.ylabel("Nombre de lloguers")
plt.savefig("PreusmensualsiPreusm2.png");

# %% [markdown]
# Veiem aqui les distribucions clarament, la de preu mensual mes cap a l'esquerra i l'altre de preu/m2 mes centrada
